# %% [markdown]
# <a href="https://colab.research.google.com/github/ShouryaSahu/davis_training/blob/main/classwork/SumOfTwoNumbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add_number(a , b):
  return a + b


num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

print(add_number(num1 , num2))
