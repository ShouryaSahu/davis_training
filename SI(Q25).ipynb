# %% [markdown]
# <a href="https://colab.research.google.com/github/ShouryaSahu/davis_training/blob/main/SI(Q25).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# One-line SI

p = float(input("P: "))
r = float(input("R: "))
t = float(input("T: "))
print("SI:", (p*r*t)/100)
# Out:
# P: 4900
# R: 5
# T: 5
# SI: 1225.0
