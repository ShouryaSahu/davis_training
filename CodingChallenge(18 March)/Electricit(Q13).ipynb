# %% [markdown]
# <a href="https://colab.research.google.com/github/ShouryaSahu/davis_training/blob/main/CodingChallenge(18%20March)/Electricit(Q13).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Electricity using ternary

u = int(input("Enter units: "))
bill = u*5 if u<=100 else 100*5+(u-100)*10

print("Bill:", bill)
# Out:
# Enter units: 320
# Bill: 2700
