# %% [markdown]
# <a href="https://colab.research.google.com/github/ShouryaSahu/davis_training/blob/main/CodingChallenge(18%20March)/SI(Using_Lambda_Q15).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# SI using lambda

p = float(input("P: "))
r = float(input("R: "))
t = float(input("T: "))

si = lambda p,r,t: (p*r*t)/100
print("SI:", si(p,r,t))
# Out:
# P: 200
# R: 100
# T: 23
# SI: 4600.0
