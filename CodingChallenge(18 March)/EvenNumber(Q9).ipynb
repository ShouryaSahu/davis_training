# %% [markdown]
# <a href="https://colab.research.google.com/github/ShouryaSahu/davis_training/blob/main/CodingChallenge(18%20March)/EvenNumber(Q9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Even numbers using list comprehension

n = int(input("Enter N: "))
evens = [i for i in range(1, n+1) if i%2==0]

print("Even numbers:", evens)
# Out:
# Enter N: 10
# Even numbers: [2, 4, 6, 8, 10]
