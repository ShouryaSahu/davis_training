# %% [markdown]
# <a href="https://colab.research.google.com/github/ShouryaSahu/davis_training/blob/main/CodingChallenge(18%20March)/Discount(Lambda_Q11).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Discount using lambda

price = float(input("Enter price: "))
discount = float(input("Enter discount: "))

func = lambda p,d: p - (p*d/100)

print("Final price:", func(price, discount))
# Out:
# Enter price: 1000
# Enter discount: 10
# Final price: 900.0
