# %% [markdown]
# <a href="https://colab.research.google.com/github/ShouryaSahu/davis_training/blob/main/CodingChallenge(18%20March)/Electricity(Using_Function_Q18).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Electricity using function

def bill(u):
    return u*5

print("Bill:", bill(int(input("Enter units: "))))
# Out:
# Enter units: 493
# Bill: 2465
