# %% [markdown]
# <a href="https://colab.research.google.com/github/ShouryaSahu/davis_training/blob/main/CodingChallenge(18%20March)/ElectricityBill(Q8).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Electricity using slab system

u = int(input("Enter units: "))

if u <= 100:
    bill = u * 5
else:
    bill = 100*5 + (u-100)*8

print("Total bill:", bill)
# Out:
# Enter units: 200
# Total bill: 1300
