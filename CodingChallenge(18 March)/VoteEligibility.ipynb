# %% [markdown]
# <a href="https://colab.research.google.com/github/ShouryaSahu/davis_training/blob/main/CodingChallenge(18%20March)/VoteEligibility.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program to check voting eligibility

# Taking input
age = int(input("Enter age: "))

# Checking condition
if age >= 18:
    print("Eligible to vote")
else:
    print("Not Eligible")
# Out:
# Enter age: 20
# Eligible to vote
