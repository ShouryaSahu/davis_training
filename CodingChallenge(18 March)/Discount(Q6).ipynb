# %% [markdown]
# <a href="https://colab.research.google.com/github/ShouryaSahu/davis_training/blob/main/CodingChallenge(18%20March)/Discount(Q6).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Discount using function

def calc_discount(p, d):
    return p * (1 - d/100)

price = float(input("Enter price: "))
discount = float(input("Enter discount %: "))

print("Final price:", calc_discount(price, discount))
# Out:
# Enter price: 200
# Enter discount %: 25
# Final price: 150.0
