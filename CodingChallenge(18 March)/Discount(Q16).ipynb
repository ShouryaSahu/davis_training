# %% [markdown]
# <a href="https://colab.research.google.com/github/ShouryaSahu/davis_training/blob/main/CodingChallenge(18%20March)/Discount(Q16).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Discount using map

p,d = map(float, input("Enter price and discount: ").split())
print("Final price:", p*(1-d/100))
# Out:
# Enter price and discount: 1000 10
# Final price: 900.0
