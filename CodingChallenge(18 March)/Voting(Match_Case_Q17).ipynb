# %% [markdown]
# <a href="https://colab.research.google.com/github/ShouryaSahu/davis_training/blob/main/CodingChallenge(18%20March)/Voting(Match_Case_Q17).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Voting using match-case

age = int(input("Enter age: "))

match age >= 18:
    case True:
        print("Eligible")
    case False:
        print("Not Eligible")
# Out:
# Enter age: 24
# Eligible
