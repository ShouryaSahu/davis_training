# %% [markdown]
# <a href="https://colab.research.google.com/github/ShouryaSahu/davis_training/blob/main/CodingChallenge(18%20March)/Discount(Q21).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Using round

p = float(input("Price: "))
d = float(input("Discount: "))
print("Final:", round(p - p*d/100,2))
# Out:
# Price: 350
# Discount: 5
# Final: 332.5
