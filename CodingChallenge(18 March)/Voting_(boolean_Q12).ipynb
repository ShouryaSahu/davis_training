# %% [markdown]
# <a href="https://colab.research.google.com/github/ShouryaSahu/davis_training/blob/main/CodingChallenge(18%20March)/Voting_(boolean_Q12).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Voting using boolean

age = int(input("Enter age: "))
print("Eligible:", age >= 18)
# Out:
# Enter age: 12
# Eligible: False
