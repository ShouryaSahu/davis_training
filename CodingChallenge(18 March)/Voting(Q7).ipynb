# %% [markdown]
# <a href="https://colab.research.google.com/github/ShouryaSahu/davis_training/blob/main/CodingChallenge(18%20March)/Voting(Q7).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Voting using ternary operator

age = int(input("Enter age: "))
print("Eligible" if age >= 18 else "Not Eligible")
# Out:
# Enter age: 20
# Eligible
