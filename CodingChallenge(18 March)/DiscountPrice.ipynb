# %% [markdown]
# <a href="https://colab.research.google.com/github/ShouryaSahu/davis_training/blob/main/CodingChallenge(18%20March)/DiscountPrice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program to calculate final price after discount

# Taking input from user
price = float(input("Enter price: "))
discount = float(input("Enter discount percentage: "))

# Calculating discount amount
discount_amount = (price * discount) / 100

# Final price after discount
final_price = price - discount_amount

# Output
print("Final price after discount:", final_price)
# Out:
# Enter price: 500
# Enter discount percentage: 25
# Final price after discount: 375.0
