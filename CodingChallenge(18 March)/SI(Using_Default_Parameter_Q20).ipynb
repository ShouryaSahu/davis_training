# %% [markdown]
# <a href="https://colab.research.google.com/github/ShouryaSahu/davis_training/blob/main/CodingChallenge(18%20March)/SI(Using_Default_Parameter_Q20).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#SI using default parameter

def si(p,r,t=1):
    return (p*r*t)/100

print("SI:", si(float(input("P: ")), float(input("R: ")), float(input("T: "))))
