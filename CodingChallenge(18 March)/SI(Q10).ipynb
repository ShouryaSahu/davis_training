# %% [markdown]
# <a href="https://colab.research.google.com/github/ShouryaSahu/davis_training/blob/main/CodingChallenge(18%20March)/SI(Q10).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Q10: SI using function

def si(p,r,t):
    return (p*r*t)/100

print("Simple Interest:", si(float(input("P: ")), float(input("R: ")), float(input("T: "))))
# Out:
# P: 100
# R: 200
# T: 20
# Simple Interest: 4000.0
