# %% [markdown]
# <a href="https://colab.research.google.com/github/ShouryaSahu/davis_training/blob/main/ClassWork/displayEvenFactor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter the Number: "))
even_factor = []
for i in range(1, num + 1):
  if(num % i == 0 and i % 2 == 0):
    even_factor.append(i)
print(even_factor)
