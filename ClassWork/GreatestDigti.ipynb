# %% [markdown]
# <a href="https://colab.research.google.com/github/ShouryaSahu/davis_training/blob/main/ClassWork/GreatestDigti.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter the number: "))
max = 0
while(num > 0):
  digit = num % 10
  if(digit > max):
    max = digit
  num = num // 10
print(f"Greatest Digit : {max}")
# Out:
# Enter the number: 6474791
# Greatest Digit : 9
